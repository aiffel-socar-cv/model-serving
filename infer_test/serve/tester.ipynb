# %% [markdown]
# ```
# curl http://127.0.0.1:8080/predictions/${MODEL_NAME} -T 3dogs.jpg -o 3dogs_mask.png
# ```

# %%
import requests
import json
from PIL import Image
import base64
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
test_image =  "/Users/tseo/Documents/Github/viai-serving/DATA/dent/test/images/20190227_10535_20402100_8621821f5ed8c37bc0b8e6e0efc9cc0a.jpg"
# save_dir = "/Users/tseo/Documents/Github/viai-serving/RESULT/dent"

# %%
with open(test_image, 'rb') as f:
    raw = f.read()

# %%
# raw = base64.b64encode(raw)
data = {'body' : raw}

# %%
# data = json.dumps(data)
# data

# %%
# data = {}
res = requests.post("http://0.0.0.0:9000/predictions/dent", data=data)

# %%
result = res.content
# result
img_np = cv2.imdecode(result, cv2.CV_LOAD_)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /var/folders/l9/47_zg5s92xn2x10nhh5p73l40000gn/T/ipykernel_13053/1489400856.py in <module>
#       1 result = res.content
#       2 # result
# ----> 3 img_np = cv2.imdecode(result)
#
# error: OpenCV(4.5.4-dev) :-1: error: (-5:Bad argument) in function 'imdecode'
# > Overload resolution failed:
# >  - imdecode() missing required argument 'flags' (pos 2)
# >  - imdecode() missing required argument 'flags' (pos 2)

# %%
encoded_img = np.fromstring(result, dtype = np.uint8)
img = cv2.imdecode(encoded_img, cv2.IMREAD_GRAYSCALE)
# Out:
# /var/folders/l9/47_zg5s92xn2x10nhh5p73l40000gn/T/ipykernel_13053/1106077271.py:1: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   encoded_img = np.fromstring(result, dtype = np.uint8)

# %%
img.shape
# Out:
# (512, 512)

# %%
plt.imshow(img)
plt.show()

# %%
img.min(), img.max(), img.dtype
# Out:
# (0, 1, dtype('uint8'))

# %%
# !curl http://0.0.0.0:9000/ping
# Out:
# {
#   "status": "Healthy"
# }

# %%
e

# %%
with open(test_image, 'rb') as f:
    raw = f.read()

# %%
import numpy as np
import io
import base64
# raw = base64.b64decode(raw)
image = np.asarray(Image.open(io.BytesIO(raw)).convert("RGB"))

# %%
import matplotlib.pyplot as plt
plt.imshow(image)
plt.show()

# %%
image.shape
# Out:
# (768, 1024, 3)
